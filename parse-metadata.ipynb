# %%
import os
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.size'] = 14

DATA_PATH = '../metadata/'

# %%
df1 = pd.read_csv(DATA_PATH + "Metadata 64-D-B1-1.csv", usecols=[0,1])
df2 = pd.read_csv(DATA_PATH + "Metadata 64-B-A1-1.csv", usecols=[0,1])

# %%
df1.shape, df2.shape
# Out:
# ((622, 2), (622, 2))

# %%
df = pd.merge(df1, df2, on="Key")
df.head()
# Out:
#                Key Value_x Value_y
# 0   BitsPerPixel    16      16
# 1   DimensionOrder  XYCZT   XYCZT
# 2   IsInterleaved   false   false
# 3   IsRGB           false   false
# 4   LittleEndian    true    true

# %%
notequal = df.Value_x != df.Value_y
notequal.sum()
# Out:
# 62

# %%
pd.set_option('display.max_colwidth', 0)
diff = df[notequal]

# %%
diff
# Out:
#                                                                                              Key  \
# 6     Series 0 Name
# 37   DisplaySetting|Channel|Id
# 68   Experiment|AcquisitionBlock|AcquisitionModeSetup|OffsetZ #1
# 71   Experiment|AcquisitionBlock|AcquisitionModeSetup|ReferenceZ #1
# 101  Experiment|AcquisitionBlock|Laser|LaserPower #4
# 226  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXX #1
# 227  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXX #2
# 228  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXX #3
# 229  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXX #4
# 230  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXY #1
# 231  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXY #2
# 232  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXY #3
# 233  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationXY #4
# 234  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYX #1
# 235  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYX #2
# 236  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYX #3
# 237  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYX #4
# 238  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYY #1
# 239  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYY #2
# 240  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYY #3
# 241  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|AiryScanTransformationYY #4
# 290  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|Id #1
# 291  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|Id #2
# 292  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|Id #3
# 293  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|Id #4
# 324  Experiment|AcquisitionBlock|MultiTrackSetup|TrackSetup|Detector|Voltage #4
# 375  Information|Document|CreationDate #1
# 376  Information|Document|Name #1
# 379  Information|Document|Title #1
# 428  Information|Image|Channel|Gain #4
# ..                                 ...
# 431  Information|Image|Channel|Id #3
# 432  Information|Image|Channel|Id #4
# 497  Information|Image|Channel|PhotonConversionFactor #1
# 498  Information|Image|Channel|PhotonConversionFactor #2
# 499  Information|Image|Channel|PhotonConversionFactor #3
# 500  Information|Image|Channel|PhotonConversionFactor #4
# 521  Information|Image|Channel|TransformationXX #1
# 522  Information|Image|Channel|TransformationXX #2
# 523  Information|Image|Channel|TransformationXX #3
# 524  Information|Image|Channel|TransformationXX #4
# 525  Information|Image|Channel|TransformationXY #1
# 526  Information|Image|Channel|TransformationXY #2
# 527  Information|Image|Channel|TransformationXY #3
# 528  Information|Image|Channel|TransformationXY #4
# 529  Information|Image|Channel|TransformationYX #1
# 530  Information|Image|Channel|TransformationYX #2
# 531  Information|Image|Channel|TransformationYX #3
# 532  Information|Image|Channel|TransformationYX #4
# 533  Information|Image|Channel|TransformationYY #1
# 534  Information|Image|Channel|TransformationYY #2
# 535  Information|Image|Channel|TransformationYY #3
# 536  Information|Image|Channel|TransformationYY #4
# 556  Information|Image|S|Scene|Position|X #1
# 557  Information|Image|S|Scene|Position|Y #1
# 558  Information|Image|S|Scene|Position|Z #1
# 559  Information|Image|Track|ChannelRef|Id #1
# 560  Information|Image|Track|ChannelRef|Id #2
# 561  Information|Image|Track|ChannelRef|Id #3
# 562  Information|Image|Track|ChannelRef|Id #4
# 596  Location
#
#                                                                                      Value_x  \
# 6    B1-1 #1
# 37   450416841127157605333742639502401459036
# 68   0.00020662500000000073
# 71   4.7509999999999997e-005
# 101  0.025000000000000001
# 226  2.5072441271770194e-310
# 227  0.71372549019607845
