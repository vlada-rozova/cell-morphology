# %%
# %run load-clean-select.ipynb
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# Morphology was measured for 610.0 cells.
#
# The numbers of cells and nuclei correspond to each other.
#
# The are no duplicated column names: True
# The are no duplicated column names: True
# Cytoplasm measurements were taken for 610 cells.
#
# The are no duplicated column names: True
# Read biomarkers normalised by to min gain
# Biomarkers were measured for 610 cells.
#
# The are no duplicated column names: True
#
# Full dataset has shape: (610, 555)
# Initial shape is: (610, 555)
# Features with zero variance:
#  Index(['centerZ_cell', 'eulernumber_cell', 'children_cytoplasm_count_cell',
# ...

# %% [markdown]
# ###### Exclude clusters at 64 kPa

# %%
measurements_red = measurements.drop(measurements[(measurements.image == '63') | (measurements.image == '64')].index)
measurements_red.shape
# Out:
# (587, 237)

# %% [markdown]
# ## 0.5 kPa

# %%
df = measurements_red.loc[measurements_red.stiffness == '0.5', :].copy()
df.shape
# Out:
# (78, 237)

# %%
plt.rcParams['figure.figsize'] = (10, 4)
df.meanintensity_ker.hist(bins=20);

# %%
df.meanintensity_vim.hist(bins=20);

# %%
plt.rcParams['figure.figsize'] = (8, 8)
sns.lmplot(x='meanintensity_vim', y='meanintensity_ker', data=df);

# %%
df[geom_cols].corrwith(df.meanintensity_vim).abs().sort_values(ascending=False).head(10)
# Out:
# meanradius_nucl          0.514845
# area_nucl                0.456458
# meanradius_cell          0.391828
# area_cell                0.383478
# perimeter_cell           0.367311
# minferetdiameter_cell    0.359339
# zernike_8_8_nucl         0.344658
# meanradius_cyto          0.341678
# maxferetdiameter_nucl    0.337494
# solidity_nucl            0.297681
# dtype: float64

# %%
sns.lmplot(x='meanradius_nucl', y='meanintensity_vim', data=df);

# %%
df.meanradius_nucl.hist(bins=25, figsize=(8,5));
